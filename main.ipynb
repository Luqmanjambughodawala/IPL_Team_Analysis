# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("ipl.csv")
df.index = df.index + 1
df.head(5)
# Out:
#                          team1                        team2  match_date  \
# 1  Royal Challengers Bangalore        Kolkata Knight Riders  2008-04-18
# 2              Kings XI Punjab          Chennai Super Kings  2008-04-19
# 3             Delhi Daredevils             Rajasthan Royals  2008-04-19
# 4               Mumbai Indians  Royal Challengers Bangalore  2008-04-20
# 5        Kolkata Knight Riders              Deccan Chargers  2008-04-20
#
#                    toss_winner toss_decision                       winner  \
# 1  Royal Challengers Bangalore         field        Kolkata Knight Riders
# 2          Chennai Super Kings           bat          Chennai Super Kings
# 3             Rajasthan Royals           bat             Delhi Daredevils
# 4               Mumbai Indians           bat  Royal Challengers Bangalore
# 5              Deccan Chargers           bat        Kolkata Knight Riders
#
#   player_of_match                                       venue        city  \
# ...

# %%
new_df = df[(df["team1"] == "Royal Challengers Bangalore") | (df["team2"] == "Royal Challengers Bangalore" )].copy()
new_df
# Out:
#                             team1                        team2  match_date  \
# 1     Royal Challengers Bangalore        Kolkata Knight Riders  2008-04-18
# 4                  Mumbai Indians  Royal Challengers Bangalore  2008-04-20
# 12    Royal Challengers Bangalore             Rajasthan Royals  2008-04-26
# 15    Royal Challengers Bangalore          Chennai Super Kings  2008-04-28
# 17               Delhi Daredevils  Royal Challengers Bangalore  2008-04-30
# ...                           ...                          ...         ...
# 999   Royal Challengers Bangalore               Delhi Capitals  2023-05-06
# 1004  Royal Challengers Bangalore               Mumbai Indians  2023-05-09
# 1011  Royal Challengers Bangalore             Rajasthan Royals  2023-05-14
# 1015          Sunrisers Hyderabad  Royal Challengers Bangalore  2023-05-18
# 1019  Royal Challengers Bangalore               Gujarat Titans  2023-05-21
#
# ...

# %%
new_df = new_df.drop(columns=["match_date","player_of_match","city","team1_players","team2_players","match_number","result","result_margin","target_runs","target_overs","super_over"])

# %%
new_df["result"] = new_df["winner"].apply(lambda x: "won" if x =="Royal Challengers Bangalore" else "lost")
new_df
# Out:
#                             team1                        team2  \
# 1     Royal Challengers Bangalore        Kolkata Knight Riders
# 4                  Mumbai Indians  Royal Challengers Bangalore
# 12    Royal Challengers Bangalore             Rajasthan Royals
# 15    Royal Challengers Bangalore          Chennai Super Kings
# 17               Delhi Daredevils  Royal Challengers Bangalore
# ...                           ...                          ...
# 999   Royal Challengers Bangalore               Delhi Capitals
# 1004  Royal Challengers Bangalore               Mumbai Indians
# 1011  Royal Challengers Bangalore             Rajasthan Royals
# 1015          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1019  Royal Challengers Bangalore               Gujarat Titans
#
#                       toss_winner toss_decision                       winner  \
# 1     Royal Challengers Bangalore         field        Kolkata Knight Riders
# ...

# %%
new_df2 = df["venue"].value_counts()
new_df2
